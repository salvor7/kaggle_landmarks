# %%
from source import Resnet50
from source import data

# %%
import keras

# %%
net = Resnet50()

# %%
batches = Resnet50.get_batches(data.path_string('data', 'sample', 'train_images'), batch_size=1)
# Out:
# Found 2 images belonging to 2 classes.

# %%
for images, categor in batches:
    print(categor)
    break
# Out:
# [[ 1.  0.]]

# %%
images
# Out:
# array([[[[ 138.,  139.,  142., ...,  128.,  102.,  136.],
#          [ 138.,  138.,  139., ...,  106.,   84.,  122.],
#          [ 137.,  138.,  138., ...,  129.,   71.,  110.],
#          ...,
#          [  77.,   78.,   70., ...,  214.,  218.,  220.],
#          [  79.,   84.,   65., ...,  157.,  137.,  137.],
#          [ 120.,  130.,  117., ...,   97.,  100.,  100.]],
#
#         [[ 110.,  111.,  112., ...,  113.,   76.,  108.],
#          [ 110.,  110.,  111., ...,   90.,   64.,  102.],
#          [ 109.,  110.,  110., ...,  113.,   55.,   94.],
#          ...,
#          [  60.,   62.,   53., ...,  178.,  185.,  187.],
#          [  58.,   64.,   43., ...,  132.,  113.,  113.],
#          [ 100.,  110.,   95., ...,   73.,   76.,   76.]],
#
#         [[  86.,   87.,   88., ...,   46.,   51.,   84.],
#          [  86.,   86.,   87., ...,   31.,   31.,   69.],
#          [  85.,   86.,   86., ...,   62.,   21.,   60.],
#          ...,
# ...

# %%
net.model.predict(images).shape
# Out:
# (1, 1000)

# %%
net.model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 3, 224, 224)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 3, 224, 224)  0           input_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 3, 230, 230)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 112, 112) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 112, 112) 256         conv1[0][0]
# ...

# %%
nn = keras.models.Model(net.model.inputs, net.model.layers[-2].output)

# %%
nn.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 3, 224, 224)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 3, 224, 224)  0           input_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 3, 230, 230)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 112, 112) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 112, 112) 256         conv1[0][0]
# ...

# %%
nn.predict(images).shape
# Out:
# (1, 2048)
