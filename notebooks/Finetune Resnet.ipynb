# %%
from source import Resnet50, data
# Out:
# Using TensorFlow backend.

# %%
nn = Resnet50()

# %%
training_batches = Resnet50.get_batches(data.path_string('data', 'sample', 'train_images'))
# Out:
# Found 993 images belonging to 8 classes.

# %%
training_batches.directory
# Out:
# 'd:\\kagglelandmarks\\data\\sample\\train_images'

# %%
validation_batches = Resnet50.get_batches(data.path_string('data', 'sample', 'valid_images'))
# Out:
# Found 991 images belonging to 8 classes.

# %%
training_batches.num_classes
# Out:
# 8

# %%
nn.finetune(training_batches)

# %%
nn.fit(batches=training_batches,
      val_batches=validation_batches,
      epochs=1
      )
# Out:
# Epoch 1/1
#   2/124 [..............................] - ETA: 2:44 - loss: 3.3161 - acc: 0.3750
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\utils\data_utils.py in get(self)
#     554             while self.is_running():
# --> 555                 inputs = self.queue.get(block=True).get()
#     556                 self.queue.task_done()
#
# C:\Anaconda3\envs\landmark\lib\multiprocessing\pool.py in get(self, timeout)
#     643         else:
# --> 644             raise self._value
#     645
#
# C:\Anaconda3\envs\landmark\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\utils\data_utils.py in get_index(uid, i)
#     391     """
# --> 392     return _SHARED_SEQUENCES[uid][i]
#     393
#
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\preprocessing\image.py in __getitem__(self, idx)
#     799                                        self.batch_size * (idx + 1)]
# --> 800         return self._get_batches_of_transformed_samples(index_array)
#     801
#
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\preprocessing\image.py in _get_batches_of_transformed_samples(self, index_array)
#    1147                            target_size=self.target_size,
# -> 1148                            interpolation=self.interpolation)
#    1149             x = img_to_array(img, data_format=self.data_format)
#
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\preprocessing\image.py in load_img(path, grayscale, target_size, interpolation)
#     348                           'The use of `array_to_img` requires PIL.')
# --> 349     img = pil_image.open(path)
#     350     if grayscale:
#
# C:\Anaconda3\envs\landmark\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2584     raise IOError("cannot identify image file %r"
# -> 2585                   % (filename if filename else fp))
#    2586
#
# OSError: cannot identify image file 'd:\\kagglelandmarks\\data\\sample\\train_images\\1256\\c038a9692b31f34d.jpg'
#
# The above exception was the direct cause of the following exception:
#
# StopIteration                             Traceback (most recent call last)
# <ipython-input-10-ba73df4b3a2b> in <module>()
#       1 nn.fit(batches=training_batches,
#       2       val_batches=validation_batches,
# ----> 3       epochs=1
#       4       )
#
# d:\kagglelandmarks\src\resnet50.py in fit(self, batches, val_batches, epochs)
#     130                                  epochs=epochs,
#     131                                  validation_data=val_batches,
# --> 132                                  validation_steps=val_epoch_steps)
#     133
#     134
#
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2143                 batch_index = 0
#    2144                 while steps_done < steps_per_epoch:
# -> 2145                     generator_output = next(output_generator)
#    2146
#    2147                     if not hasattr(generator_output, '__len__'):
#
# C:\Anaconda3\envs\landmark\lib\site-packages\keras\utils\data_utils.py in get(self)
#     559         except Exception as e:
#     560             self.stop()
# --> 561             six.raise_from(StopIteration(e), e)
#     562
#     563     def _send_sequence(self):
#
# C:\Anaconda3\envs\landmark\lib\site-packages\six.py in raise_from(value, from_value)
#
# StopIteration: cannot identify image file 'd:\\kagglelandmarks\\data\\sample\\train_images\\1256\\c038a9692b31f34d.jpg'

# %%
from PIL import Image

# %%
img_dir = r'D:\kagglelandmarks\data\sample\train_images\10028\1ead40665fcbe56b.jpg'

img = Image.open(img_dir)
